# %%
import pandas as pd
df = pd.read_csv("eval_results.csv")

# %%
df[['query']][:1]
# Out:
#                             query
# 0  how popular is the name conrad

# %%
df['ground_truth'][:1]
# Out:
# 0    It is a very popular first name for men and al...
# Name: ground_truth, dtype: str

# %%
print(df['crag_response'][:1])
# Out:
# 0    The name Conrad has maintained a steady and mo...
# Name: crag_response, dtype: str
